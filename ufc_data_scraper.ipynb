# %% [markdown]
# <a href="https://colab.research.google.com/github/grabel/MTH-398-Independent-Study/blob/master/ufc_data_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from pathlib import Path
import bs4 as bs
import urllib.request

source = urllib.request.urlopen('http://www.ufcstats.com/statistics/events/completed?page=all')
soup = bs.BeautifulSoup(source, 'lxml')

# %%
body = soup.body
every_fight_url = body.find_all('a', class_='b-link b-link_style_black')
every_fight_url = [url.get('href') for url in every_fight_url]

# %%
table = body.find('table')

# %%
table_rows = table.find_all('tr')

# %%
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['']
# ['\n\n\n\n                          UFC Fight Night: Reyes vs. Weidman\n                        \n\n                          October 18, 2019\n                        \n\n', '\n                    Boston, Massachusetts, USA\n                  ']
# ['\n\n\n                          UFC Fight Night: Joanna vs. Waterson\n                        \n\n                          October 12, 2019\n                        \n\n', '\n                    Tampa, Florida, USA\n                  ']
# ['\n\n\n                          UFC 243: Whittaker vs. Adesanya\n                        \n\n                          October 05, 2019\n                        \n\n', '\n                    Melbourne, Victoria, Australia\n                  ']
# ['\n\n\n                          UFC Fight Night: Hermansson vs. Cannonier\n                        \n\n                          September 28, 2019\n                        \n\n', '\n                    Copenhagen, Denmark\n                  ']
# ...
